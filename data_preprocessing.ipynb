# %% [markdown]
# # Data Preprocessing

# %%
import re
import string
import json
import nltk
import glob
import numpy as np
from nltk.corpus import stopwords
from nltk import ngrams
from nltk import ToktokTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nltk.download('stopwords') # downloads stopword
nltk.download('wordnet') # downloads wordnet
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
lemmatizer = WordNetLemmatizer()
tokenizer = ToktokTokenizer()
vectorizer = TfidfVectorizer()

# loads english stopwords
stopword_list = nltk.corpus.stopwords.words('english')

# %% [markdown]
# ### Module definition

# %%
def remove_punctuations(text):
    """Removes punctuation from text"""
    text = text.strip()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'[^\w\s]', '', text)
    return text


def generate_tokens(text):
    """Generates tokens using tokenizer"""
    text = text.lower()
    tokens = tokenizer.tokenize(text)
    texts = [word for word in tokens if word not in stopword_list]
    # texts = ' '.join(texts)
    return texts


def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)


def capture_lemmatization(tokens):
    """Captures lemmatization and translates word accordingly"""
    tokens = [lemmatizer.lemmatize(
        token, get_wordnet_pos(token)) for token in tokens]
    return tokens


def decontact(phrase):
    """Removes apostrophe word and numbers"""
    # number
    phrase = re.sub(r'\b\d+\b', '', phrase)

    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase


def load_articles():
    """Load multiple articles from various sources"""
    articles = []
    for filename in glob.glob('./articles/*.json'):
        try:
            with open(filename,encoding='utf-8') as f:
                data = json.load(f) 
                articles += data
        except json.decoder.JSONDecodeError as e:
                data = []

    return articles

# %% [markdown]
# __Load articles__

# %%
articles = load_articles()
print('Total documents loaded:',len(articles))

# %%
# f = open('./articles/ndtv.json', encoding="utf-8")
# articles = json.load(f)
# f.close()

article_contents = []
for article in articles:
    article_contents.append(' '.join(article['content']))
print('Content in an article', article_contents[0], end='\n')
# Out:
# Content in an article Investors and depositors tried to pull $42 billion from Silicon Valley Bank on Thursday in one of the biggest US bank runs in more than a decade, according to a Friday regulatory filing. At the close of business on March 9, the bank had a negative cash balance of $958 million, according to an order taking possession of the bank filed Friday by California's bank regulator, the Department of Financial Protection and Innovation. The order shines light on the scale of the bank run faced by the lender, which was placed into Federal Deposit Insurance Corp. receivership by the state regulator. The scale of attempted withdrawals was so large that the bank ran out of cash and ways to get it. When the Federal Reserve sent its cash letter - a list of checks and other transactions for the bank to process - to SVB, it failed to pull together enough currency to meet it, according to the California regulator. "Despite attempts from the bank, with the assistance of regulators, to transfer collateral from various sources, the bank did not meet its cash letter with the Federal Reserve," the order from Commissioner Clothilde Hewlett said. Venture withdrawals The run was sparked by a letter that Silicon Valley Bank Chief Executive Officer Greg Becker sent to shareholders Wednesday. The bank had suffered a $1.8 billion loss on the sale of US treasuries and mortgage-backed securities and outlined a plan to raise $2.25 billion of capital to shore up its finances. Customers immediately tried to pull their money, including many of the venture-capital firms the bank had cultivated over decades. Peter Thiel's Founders Fund, Coatue Management, Union Square Ventures and Founder Collective all advised their startups to pull their cash from the bank, people familiar with the matter said. The withdrawals initiated by depositors and investors amounted to $42 billion on Thursday alone, according to the regulator. Despite being in sound financial condition prior to Thursday, the California watchdog said the run "caused the bank to be incapable of paying its obligations as they come due," and it was now insolvent. The bank was then closed by the California DFPI and placed into FDIC receivership, marking the biggest failure of a US bank since the financial crisis.

# %%
res = []
for content in article_contents:
    res.append(remove_punctuations(content))

article_contents = res
print('After removal of punctuations', article_contents[0], end='\n')
# Out:
# After removal of punctuations Investors and depositors tried to pull 42 billion from Silicon Valley Bank on Thursday in one of the biggest US bank runs in more than a decade according to a Friday regulatory filing At the close of business on March 9 the bank had a negative cash balance of 958 million according to an order taking possession of the bank filed Friday by Californias bank regulator the Department of Financial Protection and Innovation The order shines light on the scale of the bank run faced by the lender which was placed into Federal Deposit Insurance Corp receivership by the state regulator The scale of attempted withdrawals was so large that the bank ran out of cash and ways to get it When the Federal Reserve sent its cash letter  a list of checks and other transactions for the bank to process  to SVB it failed to pull together enough currency to meet it according to the California regulator Despite attempts from the bank with the assistance of regulators to transfer collateral from various sources the bank did not meet its cash letter with the Federal Reserve the order from Commissioner Clothilde Hewlett said Venture withdrawals The run was sparked by a letter that Silicon Valley Bank Chief Executive Officer Greg Becker sent to shareholders Wednesday The bank had suffered a 18 billion loss on the sale of US treasuries and mortgagebacked securities and outlined a plan to raise 225 billion of capital to shore up its finances Customers immediately tried to pull their money including many of the venturecapital firms the bank had cultivated over decades Peter Thiels Founders Fund Coatue Management Union Square Ventures and Founder Collective all advised their startups to pull their cash from the bank people familiar with the matter said The withdrawals initiated by depositors and investors amounted to 42 billion on Thursday alone according to the regulator Despite being in sound financial condition prior to Thursday the California watchdog said the run caused the bank to be incapable of paying its obligations as they come due and it was now insolvent The bank was then closed by the California DFPI and placed into FDIC receivership marking the biggest failure of a US bank since the financial crisis

# %%
res = []
for content in article_contents:
    res.append(decontact(content))
    
article_contents = res
print('After removal of apostropes and numbers', article_contents[0], end='\n')
# Out:
# After removal of apostropes and numbers Investors and depositors tried to pull  billion from Silicon Valley Bank on Thursday in one of the biggest US bank runs in more than a decade according to a Friday regulatory filing At the close of business on March  the bank had a negative cash balance of  million according to an order taking possession of the bank filed Friday by Californias bank regulator the Department of Financial Protection and Innovation The order shines light on the scale of the bank run faced by the lender which was placed into Federal Deposit Insurance Corp receivership by the state regulator The scale of attempted withdrawals was so large that the bank ran out of cash and ways to get it When the Federal Reserve sent its cash letter  a list of checks and other transactions for the bank to process  to SVB it failed to pull together enough currency to meet it according to the California regulator Despite attempts from the bank with the assistance of regulators to transfer collateral from various sources the bank did not meet its cash letter with the Federal Reserve the order from Commissioner Clothilde Hewlett said Venture withdrawals The run was sparked by a letter that Silicon Valley Bank Chief Executive Officer Greg Becker sent to shareholders Wednesday The bank had suffered a  billion loss on the sale of US treasuries and mortgagebacked securities and outlined a plan to raise  billion of capital to shore up its finances Customers immediately tried to pull their money including many of the venturecapital firms the bank had cultivated over decades Peter Thiels Founders Fund Coatue Management Union Square Ventures and Founder Collective all advised their startups to pull their cash from the bank people familiar with the matter said The withdrawals initiated by depositors and investors amounted to  billion on Thursday alone according to the regulator Despite being in sound financial condition prior to Thursday the California watchdog said the run caused the bank to be incapable of paying its obligations as they come due and it was now insolvent The bank was then closed by the California DFPI and placed into FDIC receivership marking the biggest failure of a US bank since the financial crisis

# %%
article_tokens = []
for content in article_contents:
    article_tokens.append(generate_tokens(content))

print('Generation of tokens', article_tokens[0], end='\n')
# Out:
# Generation of tokens ['investors', 'depositors', 'tried', 'pull', 'billion', 'silicon', 'valley', 'bank', 'thursday', 'one', 'biggest', 'us', 'bank', 'runs', 'decade', 'according', 'friday', 'regulatory', 'filing', 'close', 'business', 'march', 'bank', 'negative', 'cash', 'balance', 'million', 'according', 'order', 'taking', 'possession', 'bank', 'filed', 'friday', 'californias', 'bank', 'regulator', 'department', 'financial', 'protection', 'innovation', 'order', 'shines', 'light', 'scale', 'bank', 'run', 'faced', 'lender', 'placed', 'federal', 'deposit', 'insurance', 'corp', 'receivership', 'state', 'regulator', 'scale', 'attempted', 'withdrawals', 'large', 'bank', 'ran', 'cash', 'ways', 'get', 'federal', 'reserve', 'sent', 'cash', 'letter', 'list', 'checks', 'transactions', 'bank', 'process', 'svb', 'failed', 'pull', 'together', 'enough', 'currency', 'meet', 'according', 'california', 'regulator', 'despite', 'attempts', 'bank', 'assistance', 'regulators', 'transfer', 'collateral', 'various', 'sources', 'bank', 'meet', 'cash', 'letter', 'federal', 'reserve', 'order', 'commissioner', 'clothilde', 'hewlett', 'said', 'venture', 'withdrawals', 'run', 'sparked', 'letter', 'silicon', 'valley', 'bank', 'chief', 'executive', 'officer', 'greg', 'becker', 'sent', 'shareholders', 'wednesday', 'bank', 'suffered', 'billion', 'loss', 'sale', 'us', 'treasuries', 'mortgagebacked', 'securities', 'outlined', 'plan', 'raise', 'billion', 'capital', 'shore', 'finances', 'customers', 'immediately', 'tried', 'pull', 'money', 'including', 'many', 'venturecapital', 'firms', 'bank', 'cultivated', 'decades', 'peter', 'thiels', 'founders', 'fund', 'coatue', 'management', 'union', 'square', 'ventures', 'founder', 'collective', 'advised', 'startups', 'pull', 'cash', 'bank', 'people', 'familiar', 'matter', 'said', 'withdrawals', 'initiated', 'depositors', 'investors', 'amounted', 'billion', 'thursday', 'alone', 'according', 'regulator', 'despite', 'sound', 'financial', 'condition', 'prior', 'thursday', 'california', 'watchdog', 'said', 'run', 'caused', 'bank', 'incapable', 'paying', 'obligations', 'come', 'due', 'insolvent', 'bank', 'closed', 'california', 'dfpi', 'placed', 'fdic', 'receivership', 'marking', 'biggest', 'failure', 'us', 'bank', 'since', 'financial', 'crisis']

# %%
res = []
i = 1
for tokens in article_tokens:
    res.append(capture_lemmatization(tokens))
    # print(i,"/", 5006)
    i += 1
article_tokens = res

print('After lemmatization', article_tokens[0], end='\n')
# Out:
# 1 / 5006
# 2 / 5006
# 3 / 5006
# 179 / 5006
# 180 / 5006
# 181 / 5006
# 182 / 5006
# 183 / 5006
# 184 / 5006
# 185 / 5006
# 186 / 5006
# 187 / 5006
# 188 / 5006
# 189 / 5006
# 190 / 5006
# 191 / 5006
# After lemmatization ['investor', 'depositor', 'try', 'pull', 'billion', 'silicon', 'valley', 'bank', 'thursday', 'one', 'big', 'u', 'bank', 'run', 'decade', 'accord', 'friday', 'regulatory', 'filing', 'close', 'business', 'march', 'bank', 'negative', 'cash', 'balance', 'million', 'accord', 'order', 'take', 'possession', 'bank', 'file', 'friday', 'california', 'bank', 'regulator', 'department', 'financial', 'protection', 'innovation', 'order', 'shine', 'light', 'scale', 'bank', 'run', 'face', 'lender', 'place', 'federal', 'deposit', 'insurance', 'corp', 'receivership', 'state', 'regulator', 'scale', 'attempt', 'withdrawal', 'large', 'bank', 'ran', 'cash', 'way', 'get', 'federal', 'reserve', 'sent', 'cash', 'letter', 'list', 'check', 'transaction', 'bank', 'process', 'svb', 'fail', 'pull', 'together', 'enough', 'currency', 'meet', 'accord', 'california', 'regulator', 'despite', 'attempt', 'bank', 'assistance', 'regulator', 'transfer', 'collateral', 'various', 'source', 'bank', 'meet', 'cash', 'letter', 'federal', 'reserve', 'order', 'commissioner', 'clothilde', 'hewlett', 'say', 'venture', 'withdrawal', 'run', 'spark', 'letter', 'silicon', 'valley', 'bank', 'chief', 'executive', 'officer', 'greg', 'becker', 'sent', 'shareholder', 'wednesday', 'bank', 'suffer', 'billion', 'loss', 'sale', 'u', 'treasury', 'mortgagebacked', 'security', 'outline', 'plan', 'raise', 'billion', 'capital', 'shore', 'finance', 'customer', 'immediately', 'try', 'pull', 'money', 'include', 'many', 'venturecapital', 'firm', 'bank', 'cultivate', 'decade', 'peter', 'thiels', 'founder', 'fund', 'coatue', 'management', 'union', 'square', 'venture', 'founder', 'collective', 'advise', 'startup', 'pull', 'cash', 'bank', 'people', 'familiar', 'matter', 'say', 'withdrawal', 'initiate', 'depositor', 'investor', 'amount', 'billion', 'thursday', 'alone', 'accord', 'regulator', 'despite', 'sound', 'financial', 'condition', 'prior', 'thursday', 'california', 'watchdog', 'say', 'run', 'cause', 'bank', 'incapable', 'pay', 'obligation', 'come', 'due', 'insolvent', 'bank', 'close', 'california', 'dfpi', 'place', 'fdic', 'receivership', 'mark', 'big', 'failure', 'u', 'bank', 'since', 'financial', 'crisis']

# %%
article_vec = list()
for tokens in article_tokens:
    modified_text = ' '.join(tokens)
    article_vec.append(modified_text)

# %% [markdown]
# # Unigram

# %%
vectorizer.fit(article_vec)
tfidf_matrix = vectorizer.transform(article_vec)

print(vectorizer.vocabulary_)
# Out:
# {'investor': 3760, 'depositor': 2020, 'try': 7478, 'pull': 5761, 'billion': 893, 'silicon': 6611, 'valley': 7724, 'bank': 761, 'thursday': 7309, 'one': 5080, 'big': 887, 'run': 6273, 'decade': 1920, 'accord': 160, 'friday': 2968, 'regulatory': 6019, 'filing': 2810, 'close': 1407, 'business': 1094, 'march': 4422, 'negative': 4867, 'cash': 1182, 'balance': 738, 'million': 4586, 'order': 5134, 'take': 7145, 'possession': 5518, 
class': 1378, 'ug': 7533, 'complete': 1532, 'july': 3916, 'new': 4895, 'academic': 143, 'session': 6490, 'begin': 812, 'august': 665, 'debut': 1919, 'edition': 2353, 'cuetug': 1826, 'mar': 4418, 'glitch': 3112, 'prompt': 5698, 'national': 4833, 'agency': 278, 'nta': 4990, 'cancel': 1134, 'multiple': 4760, 'centre': 1232, 'several': 6502, 'inform': 3636, 'cancellation': 1135, 'night': 4911, 'turn': 7498, 'away': 697, 'chairperson': 1251, 'jagadesh': 3819, 'kumar': 4051, 'certain': 1239, 'follow': 2887, 'report': 6090, 'sabotage': 6289, 'lakh': 4072, 'registration': 6011, 'gateway': 3031, 'second': 6418, 'country': 1745, 'surpass': 7063, 'jeemains': 3855, 'average': 689, 'nine': 4918, 'neetug': 4866, 'india': 3598, 'computer':  ...

# %%
tfidf_matrix.shape
# Out:
# (191, 8111)

# %%
feature_names = vectorizer.get_feature_names_out()
tfidf_scores = tfidf_matrix.toarray()

# Define the number of top features to display in the bar chart
n = 10

# Loop over each document and create a bar chart of the top n TF-IDF scores
for i, doc in enumerate(article_vec):
    # Get the indices of the top n TF-IDF scores for the current document
    if i == 10: break
    top_indices = np.argsort(tfidf_scores[i])[-n:]

    # Get the top n feature names and TF-IDF scores for the current document
    top_features = [feature_names[j] for j in top_indices]
    top_scores = [tfidf_scores[i][j] for j in top_indices]

    # Create a horizontal bar chart of the top n TF-IDF scores
    fig, ax = plt.subplots()
    ax.barh(top_features, top_scores)
    ax.set_title("TF-IDF Scores for Document {}".format(i+1))
    ax.set_xlabel("TF-IDF Score")
    plt.show()

# %% [markdown]
# # Bigram

# %%
vectorizer = TfidfVectorizer(ngram_range=(2,2))
vectorizer.fit(article_vec)
tfidf_matrix = vectorizer.transform(article_vec)

print(vectorizer.vocabulary_)
# Out:
# {'investor depositor': 15891, 'depositor try': 8558, 'try pull': 32780, 'pull billion': 24948, 'billion silicon': 3646, 'silicon valley': 28962, 'valley bank': 33745, 'bank thursday': 3174, 'thursday one': 32044, 'one big': 21621, 'big bank': 3574, 'bank run': 3166, 'run decade': 26962, 'decade accord': 8131, 'accord friday': 277, 'friday regulatory': 12582, 'regulatory filing': 25901, 'filing close': 11770, 'close business': 5785, 'business march': 4247, 'march bank': 18625, 'bank negative': 3153, 'negative cash': 20708, 'cash balance': 4746, 'balance million': 3057, 'million accord': 19391, 'accord order': 293, 'order take': 22030, 'take possession': 31260, 'possession bank': 23839, 'bank file': 3138, 'file friday': 11764, 'friday california': 12565, 'california bank': 4312, 'bank regulator': 3162, 'regulator department': 25890, 'department financial': 8513, 'financial protection': 11851, 'protection innovation': 24763, 'innovation order': 15538, 'order shine': 22026, 'shine light': 28762, 'light scale': 17679, 'scale bank': 27736, 'run face': 26964, 'face lender': 11348, 'lender place': 17477, 'place federal': 23335, 'federal deposit': 11626, 'deposit insurance': 8550, 'insurance corp': 15676, 'corp receivership': 6986, 'receivership state': 25573, 'state regulator': 30032, 'regulator scale': 25895, 'scale attempt': 27735, 'attempt withdrawal': 2701, 'withdrawal large': 34786, 'large bank': 17013, 'bank ran': 3160, 'ran cash': 25292, 'cash way': 4751, 'way get': 34396, 'get federal': 13020, 'federal reserve': 11632, 'reserve sent': 26411, 'sent cash': 28338, 'cash letter': 4748, 'letter list': 17534, 'list check': 17832, 'check transaction': 5315, 'transaction bank': 32577, 'bank process': 3158, 'process svb': 24485, 'svb fail': 31013, 'fail pull': 11421, 'pull together': 24954, 'together enough': 32303, 'enough currency': 10398, 'currency meet': 7673, 'meet accord': 19098, 'accord california': 266, 'california regulator': 4315, 'regulator despite': 25891, 'despite attempt': 8628, 'attempt bank': 2679, 'bank assistance': 3128, 'assistance regulator': 2519, 'regulator transfer': 25897, 'transfer collateral': 32585, 'collateral various': 5958, 'various source': 33803, 'source bank': 29417, 'bank meet': 3152, 'meet cash': 19100, 'letter federal': 17530, 'reserve order': 26408, 'order commissioner': 21997, 'commissioner clothilde': 6157, 'clothilde hewlett': 5833, 'hewlett say': 14094, 'say venture': 27708, 'venture withdrawal': 33858, 'withdrawal run': 34788, 'run spark': 26969, 'spark letter': 29511, 'letter silicon': 17540, 'bank chief': 3130, 'chief executive': 5354, 'executive officer': 11053, 'officer greg': 21475, 'greg becker': 13510, 'becker sent': 3295, 'sent shareholder': 28350, 'shareholder wednesday': 28713, 'wednesday bank': 34502, 'bank suffer': 3171, 'suffer billion': 30708, 'billion loss': 3638, 'loss sale': 18092, 'sale treasury': 27088, 'treasury mortgagebacked': 32636, 'mortgagebacked security': 19988, 'security outline': 28136, 'outline plan': 22164, 'plan raise': 23379, 'raise billion': 25235, 'billion capital': 3628, 'capital shore': 4521, 'shore finance': 28799, 'finance customer': 11836, 'customer immediately': 7740, 'immediately try': 14843, 'pull money': 24952, 'money include': 19869, 'include many': 15027, 'many venturecapital': 18600, 'venturecapital firm': 33860, 'firm bank': 11941, 'bank cultivate': 3134, 'cultivate decade': 7649, 'decade peter': 8145, 'peter thiels': 23168, 'thiels founder': 31848, 'founder fund': 12468, 'fund coatue': 12694, 'coatue management': 5905, 'management union': 18500, 'union square': 33283, 'square venture': 29697, 'venture founder': 33853, 'founder collective': 12467, 'collective advise': 5979, 'advise startup': 779, 'startup pull': 29933, 'pull cash': 24949, 'cash bank': 4747, 'bank people': 3155, 'people familiar': 22904, 'familiar matter': 11464, 'matter say': 18829, 'say withdrawal': 27723, 'withdrawal initiate': 34785, 'initiate depositor': 15502, 'depositor inve ...

# %%
tfidf_matrix.shape
# Out:
# (191, 35543)

# %%
feature_names = vectorizer.get_feature_names_out()
tfidf_scores = tfidf_matrix.toarray()

# Define the number of top features to display in the bar chart
n = 10

# Loop over each document and create a bar chart of the top n TF-IDF scores
for i, doc in enumerate(article_vec):
    # Get the indices of the top n TF-IDF scores for the current document
    if i == 10: break
    top_indices = np.argsort(tfidf_scores[i])[-n:]

    # Get the top n feature names and TF-IDF scores for the current document
    top_features = [feature_names[j] for j in top_indices]
    top_scores = [tfidf_scores[i][j] for j in top_indices]

    # Create a horizontal bar chart of the top n TF-IDF scores
    fig, ax = plt.subplots()
    ax.barh(top_features, top_scores)
    ax.set_title("TF-IDF Scores for Document {}".format(i+1))
    ax.set_xlabel("TF-IDF Score")
    plt.show()
