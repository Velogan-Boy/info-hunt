# %% [markdown]
# # Data Preprocessing

# %%
import re
import string
import json
import nltk
from nltk.corpus import stopwords
from nltk import ToktokTokenizer
from nltk import ngrams

tokenizer = ToktokTokenizer()

# %%
nltk.download('stopwords')

# %% [markdown]
# **Loading Data**

# %%
stopword_list = nltk.corpus.stopwords.words('english')


def remove_punctuations(text):
    text = text.strip()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'[^\w\s]', '', text)
    return text


def generate_tokens(text):
    text = text.lower()
    tokens = tokenizer.tokenize(text)
    texts = [word for word in tokens if word not in stopword_list]
    # texts = ' '.join(texts)
    return texts


def decontact(phrase):
	# specific
	phrase = re.sub(r"won't", "will not", phrase)
	phrase = re.sub(r"can\'t", "can not", phrase)
	phrase = re.sub(r'\b\d+\b', '', phrase)

	# general
	phrase = re.sub(r"n\'t", " not", phrase)
	phrase = re.sub(r"\'re", " are", phrase)
	phrase = re.sub(r"\'s", " is", phrase)
	phrase = re.sub(r"\'d", " would", phrase)
	phrase = re.sub(r"\'ll", " will", phrase)
	phrase = re.sub(r"\'t", " not", phrase)
	phrase = re.sub(r"\'ve", " have", phrase)
	phrase = re.sub(r"\'m", " am", phrase)
	return phrase

# %%
ndtvf = open('./articles/ndtv.json', encoding="utf8")
data = json.load(ndtvf)

for article in data:
    content = ' '.join(article['content'])
    content = remove_punctuations(content)
    content = decontact(content)
    tokens = generate_tokens(content)
    ngrams = ngrams(tokens, 3)
    for ngram in ngrams:
    	print(ngram)

ndtvf.close()
# Out:
# ('investors', 'depositors', 'tried')
# ('depositors', 'tried', 'pull')
# ('tried', 'pull', 'billion')
# ('pull', 'billion', 'silicon')
# ('billion', 'silicon', 'valley')
# ('silicon', 'valley', 'bank')
# ('valley', 'bank', 'thursday')
# ('bank', 'thursday', 'one')
# ('thursday', 'one', 'biggest')
# ('one', 'biggest', 'us')
# ('biggest', 'us', 'bank')
# ('us', 'bank', 'runs')
# ('bank', 'runs', 'decade')
# ('runs', 'decade', 'according')
# ('decade', 'according', 'friday')
# ('according', 'friday', 'regulatory')
# ('friday', 'regulatory', 'filing')
# ('regulatory', 'filing', 'close')
# ('filing', 'close', 'business')
# ('close', 'business', 'march')
# ('business', 'march', 'bank')
# ('march', 'bank', 'negative')
# ('bank', 'negative', 'cash')
# ('negative', 'cash', 'balance')
# ('cash', 'balance', 'million')
# ('balance', 'million', 'according')
# ('million', 'according', 'order')
# ('according', 'order', 'taking')
# ('order', 'taking', 'possession')
# ('taking', 'possession', 'bank')
# ('possession', 'bank', 'filed')
# ('bank', 'filed', 'friday')
# ('filed', 'friday', 'californias')
# ('friday', 'californias', 'bank')
# ('californias', 'bank', 'regulator')
# ('bank', 'regulator', 'department')
# ('regulator', 'department', 'financial')
# ('department', 'financial', 'protection')
# ('financial', 'protection', 'innovation')
# ('protection', 'innovation', 'order')
# ('innovation', 'order', 'shines')
# ('order', 'shines', 'light')
# ('shines', 'light', 'scale')
# ('light', 'scale', 'bank')
# ('scale', 'bank', 'run')
# ('bank', 'run', 'faced')
# ('run', 'faced', 'lender')
# ('faced', 'lender', 'placed')
# ('lender', 'placed', 'federal')
# ('placed', 'federal', 'deposit')
# ('federal', 'deposit', 'insurance')
# ('deposit', 'insurance', 'corp')
# ('insurance', 'corp', 'receivership')
# ('corp', 'receivership', 'state')
# ('receivership', 'state', 'regulator')
# ('state', 'regulator', 'scale')
# ('regulator', 'scale', 'attempted')
# ('scale', 'attempted', 'withdrawals')
# ('attempted', 'withdrawals', 'large')
# ('withdrawals', 'large', 'bank')
# ('large', 'bank', 'ran')
# ('bank', 'ran', 'cash')
# ('ran', 'cash', 'ways')
# ('cash', 'ways', 'get')
# ('ways', 'get', 'federal')
# ('get', 'federal', 'reserve')
# ('federal', 'reserve', 'sent')
# ('reserve', 'sent', 'cash')
# ('sent', 'cash', 'letter')
# ('cash', 'letter', 'list')
# ('letter', 'list', 'checks')
# ('list', 'checks', 'transactions')
# ('checks', 'transactions', 'bank')
# ('transactions', 'bank', 'process')
# ('bank', 'process', 'svb')
# ('process', 'svb', 'failed')
# ('svb', 'failed', 'pull')
# ('failed', 'pull', 'together')
# ('pull', 'together', 'enough')
# ('together', 'enough', 'currency')
# ('enough', 'currency', 'meet')
# ('currency', 'meet', 'according')
# ('meet', 'according', 'california')
# ('according', 'california', 'regulator')
# ('california', 'regulator', 'despite')
# ('regulator', 'despite', 'attempts')
# ('despite', 'attempts', 'bank')
# ('attempts', 'bank', 'assistance')
# ('bank', 'assistance', 'regulators')
# ('assistance', 'regulators', 'transfer')
# ('regulators', 'transfer', 'collateral')
# ('transfer', 'collateral', 'various')
# ('collateral', 'various', 'sources')
# ('various', 'sources', 'bank')
# ('sources', 'bank', 'meet')
# ('bank', 'meet', 'cash')
# ('meet', 'cash', 'letter')
# ('cash', 'letter', 'federal')
# ('letter', 'federal', 'reserve')
# ('federal', 'reserve', 'order')
# ('reserve', 'order', 'commissioner')
# ('order', 'commissioner', 'clothilde')
# ('commissioner', 'clothilde', 'hewlett')
# ('clothilde', 'hewlett', 'said')
# ('hewlett', 'said', 'venture')
# ('said', 'venture', 'withdrawals')
# ('venture', 'withdrawals', 'run')
# ('withdrawals', 'run', 'sparked')
# ('run', 'sparked', 'letter')
# ('sparked', 'letter', 'silicon')
# ('letter', 'silicon', 'valley')
# ('silicon', 'valley', 'bank')
# ('valley', 'bank', 'chief')
# ('bank', 'chief', 'executive')
# ('chief', 'executive', 'officer')
# ('executive', 'officer', 'greg')
# ('officer', 'greg', 'becker')
# ('greg', 'becker', 'sent')
# ('becker', 'sent', 'shareholders')
# ('sent', 'shareholders', 'wednesday')
# ('shareholders', 'wednesday', 'bank')
# ('wednesday', 'bank', 'suffered')
# ('bank', 'suffered', 'billion')
# ('suffered', 'billion', 'loss')
# ('billion', 'loss', 'sale')
# ('loss', 'sale', 'us')
# ('sale', 'us', 'treasuries')
# ('us', 'treasuries', 'mortgagebacked')
# ('treasuries', 'mortgagebacked', 'securities')
# ('mortgagebacked', 'securities', 'outlined')
# ('securities', 'outlined', 'plan')
# ('outlined', 'plan', 'raise')
# ('plan', 'raise', 'billion')
# ('raise', 'billion', 'capital')
# ('billion', 'capital', 'shore')
# ('capital', 'shore', 'finances')
# ('shore', 'finances', 'customers')
# ('finances', 'customers', 'immediately')
# ('customers', 'immediately', 'tried')
# ('immediately', 'tried', 'pull')
# ('tried', 'pull', 'money')
# ('pull', 'money', 'including')
# ('money', 'including', 'many')
# ('including', 'many', 'venturecapital')
# ('many', 'venturecapital', 'firms')
# ('venturecapital', 'firms', 'bank')
# ('firms', 'bank', 'cultivated')
# ('bank', 'cultivated', 'decades')
# ('cultivated', 'decades', 'peter')
# ('decades', 'peter', 'thiels')
# ('peter', 'thiels', 'founders')
# ('thiels', 'founders', 'fund')
# ('founders', 'fund', 'coatue')
# ('fund', 'coatue', 'management')
# ('coatue', 'management', 'union')
# ('management', 'union', 'square')
# ('union', 'square', 'ventures')
# ('square', 'ventures', 'founder')
# ('ventures', 'founder', 'collective')
# ('founder', 'collective', 'advised')
# ('collective', 'advised', 'startups')
# ('advised', 'startups', 'pull')
# ('startups', 'pull', 'cash')
# ('pull', 'cash', 'bank')
# ('cash', 'bank', 'people')
# ('bank', 'people', 'familiar')
# ('people', 'familiar', 'matter')
# ('familiar', 'matter', 'said')
# ('matter', 'said', 'withdrawals')
# ('said', 'withdrawals', 'initiated')
# ('withdrawals', 'initiated', 'depositors')
# ('initiated', 'depositors', 'investors')
# ('depositors', 'investors', 'amounted')
# ('investors', 'amounted', 'billion')
# ('amounted', 'billion', 'thursday')
# ('billion', 'thursday', 'alone')
# ('thursday', 'alone', 'according')
# ('alone', 'according', 'regulator')
# ('according', 'regulator', 'despite')
# ('regulator', 'despite', 'sound')
# ('despite', 'sound', 'financial')
# ('sound', 'financial', 'condition')
# ('financial', 'condition', 'prior')
# ('condition', 'prior', 'thursday')
# ('prior', 'thursday', 'california')
# ('thursday', 'california', 'watchdog')
# ('california', 'watchdog', 'said')
# ('watchdog', 'said', 'run')
# ('said', 'run', 'caused')
# ('run', 'caused', 'bank')
# ('caused', 'bank', 'incapable')
# ('bank', 'incapable', 'paying')
# ('incapable', 'paying', 'obligations')
# ('paying', 'obligations', 'come')
# ('obligations', 'come', 'due')
# ('come', 'due', 'insolvent')
# ('due', 'insolvent', 'bank')
# ('insolvent', 'bank', 'closed')
# ('bank', 'closed', 'california')
# ('closed', 'california', 'dfpi')
# ('california', 'dfpi', 'placed')
# ('dfpi', 'placed', 'fdic')
# ('placed', 'fdic', 'receivership')
# ('fdic', 'receivership', 'marking')
# ('receivership', 'marking', 'biggest')
# ('marking', 'biggest', 'failure')
# ('biggest', 'failure', 'us')
# ('failure', 'us', 'bank')
# ('us', 'bank', 'since')
# ('bank', 'since', 'financial')
# ('since', 'financial', 'crisis')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 9
#       7 content = decontact(content)
#       8 tokens = generate_tokens(content)
# ----> 9 ngrams = ngrams(tokens, 3)
#      10 for ngram in ngrams:
#      11 	print(ngram)
#
# TypeError: 'zip' object is not callable
